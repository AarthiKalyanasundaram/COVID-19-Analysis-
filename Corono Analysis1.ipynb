# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

#Data from the https://ourworldindata.org/coronavirus-source-data

#Loading the data from csv to dataframe with name as data
data=pd.read_csv("C:/Users/aarthiksundaram/Downloads/full_data.csv")

#Viewing the first five elements 
data.head()
# Out:
#          date     location  new_cases  new_deaths  total_cases  total_deaths
# 0  2019-12-31  Afghanistan          0           0            0             0
# 1  2020-01-01  Afghanistan          0           0            0             0
# 2  2020-01-02  Afghanistan          0           0            0             0
# 3  2020-01-03  Afghanistan          0           0            0             0
# 4  2020-01-04  Afghanistan          0           0            0             0

# %%
data.shape
# Out:
# (6824, 6)

# %%
#finding the null values in the dataset

data.isnull().sum()
# Out:
# date            0
# location        0
# new_cases       0
# new_deaths      0
# total_cases     0
# total_deaths    0
# dtype: int64

# %%
Indiadata=data.loc[(data['location']=="India")] 
Indiadata.shape
# Out:
# (85, 6)

# %%
Indiadata
# Out:
#             date location  new_cases  new_deaths  total_cases  total_deaths
# 2680  2019-12-31    India          0           0            0             0
# 2681  2020-01-01    India          0           0            0             0
# 2682  2020-01-02    India          0           0            0             0
# 2683  2020-01-03    India          0           0            0             0
# 2684  2020-01-04    India          0           0            0             0
# 2685  2020-01-05    India          0           0            0             0
# 2686  2020-01-06    India          0           0            0             0
# 2687  2020-01-07    India          0           0            0             0
# 2688  2020-01-08    India          0           0            0             0
# 2689  2020-01-09    India          0           0            0             0
# 2690  2020-01-10    India          0           0            0             0
# ...

# %%
for col in data.columns: 
    print(col)
# Out:
# date
# location
# new_cases
# new_deaths
# total_cases
# total_deaths

# %%
import matplotlib.pyplot as plt
plt.scatter(Indiadata['date'],Indiadata['total_deaths'], title="Graph analysis")
plt.xlabel("Dates")
plt.ylabel("Total number of Deaths")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-104-a2e0d630d4cd> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.scatter(Indiadata['date'],Indiadata['total_deaths'], title="Graph analysis")
#       3 plt.xlabel("Dates")
#       4 plt.ylabel("Total number of Deaths")
#       5 plt.show()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3468                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3469                          linewidths=linewidths, verts=verts,
# -> 3470                          edgecolors=edgecolors, data=data, **kwargs)
#    3471     finally:
#    3472         ax._hold = washold
#
# ...
